# %% [markdown]
# # Problemas de distribución de probabilidad

# %% [markdown]
# ## Distribución binomial
#
# En teoría de la probabilidad y estadística, la distribución binomial es la distribución de probabilidad discreta que da sólo dos resultados posibles en un experimento; por ejemplo, al lanzar una moneda, puede salir cara o cruz.

# %%
from scipy.stats import binom

# Definir todas las funciones de probabilidad relacionadas con esta distribución.

def dbinom(x, size, prob = 0.5):
    """
    Calcula la estimación puntual de la distribución binomial.
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calcula el acumulado de la distribución binomial.
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calcula la función cuantil a partir de la distribución binomial.
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Genera variables aleatorias a partir de la distribución binomial.
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Distribución binomial(10, 0.2), dónde n = 10 es el número de ensayos y p = 0.2 es la probabilidad de éxito en un solo ensayo
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Ejercicio 1
#
# Escriba las funciones anteriores pero para distribuciones normales y uniformes.

# %% [markdown]
# ## DISTRIBUCION NORMAL
#
#
# ## Parámetros:
#
#
#     mean (μμ) → Media.
#     std_dev (σσ) → Desviación estándar.

# %%
# TODO


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


mean = 0  
std_dev = 1 
samples = np.random.normal(mean, std_dev, 10000)

from scipy.stats import norm

def dnorm(x, mean=0, std_dev=1):
    """ Calcula la densidad de probabilidad de la distribución normal. """
    return norm.pdf(x, loc=mean, scale=std_dev)

def pnorm(q, mean=0, std_dev=1):
    """ Calcula la probabilidad acumulada de la distribución normal. """
    return norm.cdf(q, loc=mean, scale=std_dev)

def qnorm(p, mean=0, std_dev=1):
    """ Calcula el cuantil (percentil) de la distribución normal. """
    return norm.ppf(p, loc=mean, scale=std_dev)

def rnorm(n, mean=0, std_dev=1):
    """ Genera variables aleatorias de la distribución normal. """
    return norm.rvs(loc=mean, scale=std_dev, size=n)

# %%
import numpy as np

np.random.seed(42)

# Pruebas para la distribución normal
print(f"Normal PDF en x=0 (mean=0, std=1): {dnorm(0):.4f}")
print(f"Normal CDF en x=0 (mean=0, std=1): {pnorm(0):.4f}")
print(f"Normal Quantile en p=0.95 (mean=0, std=1): {qnorm(0.95):.4f}")
print(f"Primeros 5 valores (mean=0, std=1): {rnorm(5)}")
# Out:
# Normal PDF en x=0 (mean=0, std=1): 0.3989
# Normal CDF en x=0 (mean=0, std=1): 0.5000
# Normal Quantile en p=0.95 (mean=0, std=1): 1.6449
# Primeros 5 valores (mean=0, std=1): [ 0.49671415 -0.1382643   0.64768854  1.52302986 -0.23415337]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x_normal = np.linspace(-4, 4, 1000)

# Funciones de probabilidad
pdf_normal = norm.pdf(x_normal, loc=mean, scale=std_dev)
cdf_normal = norm.cdf(x_normal, loc=mean, scale=std_dev)

# Generar valores aleatorios
random_normal = norm.rvs(loc=mean, scale=std_dev, size=1000)


# Crear subgráficos
fig, axes = plt.subplots(3, 1, figsize=(6, 12))


# PDF Normal
axes[0].plot(x_normal, pdf_normal, label="PDF Normal", color="blue")
axes[0].set_title("Distribución Normal - PDF")
axes[0].legend()

# CDF Normal
axes[1].plot(x_normal, cdf_normal, label="CDF Normal", color="red")
axes[1].set_title("Distribución Normal - CDF")
axes[1].legend()

# Histograma Normal
axes[2].hist(random_normal, bins=30, density=True, alpha=0.6, color="blue")
axes[2].set_title("Muestra Aleatoria - Normal")


# Ajustes finales
plt.tight_layout()
plt.show()

# %% [markdown]
# ## DISTRIBUCION UNIFORME
#
#
# ## Parámetros:
#
#     a → Límite inferior.
#     b → Límite superior.

# %%
from scipy.stats import uniform

def dunif(x, a=0, b=1):
    """ Calcula la densidad de probabilidad de la distribución uniforme. """
    return uniform.pdf(x, loc=a, scale=b-a)

def punif(q, a=0, b=1):
    """ Calcula la probabilidad acumulada de la distribución uniforme. """
    return uniform.cdf(q, loc=a, scale=b-a)

def qunif(p, a=0, b=1):
    """ Calcula el cuantil (percentil) de la distribución uniforme. """
    return uniform.ppf(p, loc=a, scale=b-a)

def runif(n, a=0, b=1):
    """ Genera variables aleatorias de la distribución uniforme. """
    return uniform.rvs(loc=a, scale=b-a, size=n)

# %%
import numpy as np

np.random.seed(42)

# Pruebas para la distribución uniforme
print(f"Uniform PDF en x=0.5 (a=0, b=1): {dunif(0.5):.4f}")
print(f"Uniform CDF en x=0.5 (a=0, b=1): {punif(0.5):.4f}")
print(f"Uniform Quantile en p=0.95 (a=0, b=1): {qunif(0.95):.4f}")
print(f"Primeros 5 valores (a=0, b=1): {runif(5)}")
# Out:
# Uniform PDF en x=0.5 (a=0, b=1): 1.0000
# Uniform CDF en x=0.5 (a=0, b=1): 0.5000
# Uniform Quantile en p=0.95 (a=0, b=1): 0.9500
# Primeros 5 valores (a=0, b=1): [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import  uniform

x_uniform = np.linspace(-1, 2, 1000)

a, b = 0, 1  # Límites p

# Funciones de probabilidad
pdf_uniform = uniform.pdf(x_uniform, loc=a, scale=b-a)
cdf_uniform = uniform.cdf(x_uniform, loc=a, scale=b-a)

# Generar valores aleatorios
random_uniform = uniform.rvs(loc=a, scale=b-a, size=1000)

# Crear subgráficos
fig, axes = plt.subplots(3, 1, figsize=(6, 12))


#  PDF Uniforme
axes[0].plot(x_uniform, pdf_uniform, label="PDF Uniforme", color="green")
axes[0].set_title("Distribución Uniforme - PDF")
axes[0].legend()

# CDF Uniforme
axes[1].plot(x_uniform, cdf_uniform, label="CDF Uniforme", color="orange")
axes[1].set_title("Distribución Uniforme - CDF")
axes[1].legend()

# Histograma Uniforme
axes[2].hist(random_uniform, bins=30, density=True, alpha=0.6, color="green")
axes[2].set_title("Muestra Aleatoria - Uniforme")

# Ajustes finales
plt.tight_layout()
plt.show()
